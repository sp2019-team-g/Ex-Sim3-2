# %%
import pandas as pd
from pandas.plotting import table
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("data/EUCALLepsilon.csv",index_col="#")

# %%
plt.plot(df.epsilon,df.result)
